# %% [markdown]
# <a href="https://colab.research.google.com/github/saxon0955/Python-365-HW/blob/main/PROJECT_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#台北1996~2020年總人口/男女總人口
data = pd.read_csv("https://raw.githubusercontent.com/saxon0955/Project-1/main/people.csv")
data.head(5)
# Out:
#    Year      Total  Total/MAN  Total/FEMAN
# 0  1996  2605374.0  1302249.0    1303125.0
# 1  1997  2598493.0  1295637.0    1302856.0
# 2  1998  2639939.0  1311789.0    1328150.0
# 3  1999  2641312.0  1309434.0    1331878.0
# 4  2000  2646474.0  1309308.0    1337166.0

# %%
data.describe()
# Out:
#               Year         Total     Total/MAN   Total/FEMAN
# count    25.000000  2.500000e+01  2.500000e+01  2.500000e+01
# mean   2008.000000  2.643868e+06  1.285121e+06  1.358747e+06
# std       7.359801  3.184755e+04  1.770128e+04  3.205792e+04
# min    1996.000000  2.598493e+06  1.238618e+06  1.302856e+06
# 25%    2002.000000  2.622472e+06  1.276343e+06  1.336169e+06
# 50%    2008.000000  2.639939e+06  1.286303e+06  1.351713e+06
# 75%    2014.000000  2.668572e+06  1.295637e+06  1.387865e+06
# max    2020.000000  2.704810e+06  1.311789e+06  1.409348e+06

# %%
data.iloc[0:5, 0:2]
# Out:
#    Year      Total
# 0  1996  2605374.0
# 1  1997  2598493.0
# 2  1998  2639939.0
# 3  1999  2641312.0
# 4  2000  2646474.0

# %%
data["Total"].hist(bins=100)
plt.xlabel("Year")
plt.ylabel("person")
plt.title("TAIPEI PEOPLE GROW")
plt.show()
